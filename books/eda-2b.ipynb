# %%
1+1
# Out:
# 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
from pathlib import Path

# Set display options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
pd.set_option('display.float_format', '{:.2f}'.format)

# Set plotting style
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['font.size'] = 10

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
data_fn = "../data/dl/FY2026_All_Contracts_Full_20251207_1.csv"

df = pd.read_csv(data_fn)

print(f"Loaded {len(df):,} records")
print(f"Data shape: {df.shape}")
# Out:
# /tmp/ipykernel_117511/662290530.py:3: DtypeWarning: Columns (47,68,71,72,81,107,108,115,116,117,118,135,136,165,179,180) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(data_fn)
# Loaded 192,181 records
# Data shape: (192181, 297)

# %%
# data_fn = "../data/dl/FY2025_All_Contracts_Full_20251207_1.csv"
data_fn = "../data/dl/FY2025_All_Contracts_Full_20251207_1_snipped.csv"

df = pd.read_csv(data_fn)

print(f"Loaded {len(df):,} records")
print(f"Data shape: {df.shape}")
# Out:
# /tmp/ipykernel_125796/597516756.py:4: DtypeWarning: Columns (47,68,71,72,81,107,108,115,116,135,136,164,165,179,180) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(data_fn)
# Loaded 500,000 records
# Data shape: (500000, 297)

# %%
df.action_date.min()
# Out:
# '2025-08-23'

# %%
df.action_date.max()
# Out:
# '2025-09-30'

# %%
df.award_type.value_counts()
# Out:
# award_type
# DELIVERY ORDER         279543
# BPA CALL               107264
# PURCHASE ORDER          69504
# DEFINITIVE CONTRACT     15732
# Name: count, dtype: int64

# %%
int(df.federal_action_obligation.sum())
# Out:
# 114343580839

# %%
total = 114_343_580_839

# %%
mult = 6200/500

# %%
total * mult
# Out:
# 1417860402403.6

# %%
expected_total = 1_417_860_402_403

# %%
192_000/60
# Out:
# 3200.0

# %%
6_200_000 / 365
# Out:
# 16986.301369863013

# %%
sum(df.federal_action_obligation > 0)
# Out:
# 133103

# %%
df.award_type.value_counts()
# Out:
# award_type
# DELIVERY ORDER         72464
# BPA CALL               50759
# PURCHASE ORDER         33715
# DEFINITIVE CONTRACT     6017
# Name: count, dtype: int64

# %%
df.action_date.value_counts()
# Out:
# action_date
# 2025-11-25    16971
# 2025-10-02     8699
# 2025-10-01     8217
# 2025-10-09     7936
# 2025-12-03     7931
# 2025-12-02     7653
# 2025-10-03     7539
# 2025-11-20     7007
# 2025-11-26     6104
# 2025-12-01     5917
# 2025-11-19     5193
# 2025-11-21     5036
# 2025-11-24     4493
# 2025-11-18     4445
# 2025-11-13     4008
# 2025-10-30     3856
# 2025-11-03     3507
# 2025-11-14     3497
# 2025-10-23     3435
# 2025-11-06     3427
# 2025-10-16     3348
# 2025-11-17     3250
# 2025-10-29     3019
# 2025-11-04     2848
# 2025-11-05     2728
# 2025-11-12     2696
# 2025-10-14     2675
# 2025-10-22     2667
# 2025-10-08     2649
# 2025-10-15     2643
# 2025-12-04     2602
# 2025-10-21     2547
# 2025-10-17     2537
# 2025-10-28     2409
# 2025-10-31     2394
# 2025-10-07     2251
# 2025-10-27     2120
# 2025-10-20     2034
# 2025-11-28     2006
# 2025-10-06     1883
# 2025-10-24     1806
# 2025-10-10     1664
# 2025-11-27     1637
# 2025-11-22     1275
# ...
