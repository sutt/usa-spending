# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
from pathlib import Path
import glob

# Set display options
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
pd.set_option('display.float_format', '{:.2f}'.format)

# Set plotting style
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (14, 6)
plt.rcParams['font.size'] = 10

# %%
data_fn_tx = "../data/round3/transactions_normalized_2026-01-09_13-04-38.json"
data_fn_aw = "../data/round3/awards_normalized_2026-01-10_09-30-16.json"

with open(data_fn_tx, 'r') as f:
    transactions_data = json.load(f)
df_tx = pd.DataFrame(transactions_data)

with open(data_fn_aw, 'r') as f:
    awards_data = json.load(f)
df_aw = pd.DataFrame(awards_data)

# %%
df_tx.shape, df_aw.shape
# Out:
# ((21067, 22), (10000, 20))

# %%
# new_tx

# %%
mask_new_tx = ((df_tx['modification_number'] == '0') | (df_tx['action_type_description'] == 'NEW'))

# %%
df_new_tx = df_tx[mask_new_tx]

# %%
df_new_tx.shape
# Out:
# (1643, 22)

# %%
# threshold amount

# %%
thresh_amount = 900_000
mask_amt = df_new_tx.federal_action_obligation >= thresh_amount
df_new_tx = df_new_tx[mask_amt]
df_new_tx.shape
# Out:
# (1548, 22)

# %%
# joining

# %%
# Check unique award_ids in each dataset
print("=== Award ID Coverage ===")
print(f"Unique award_ids in new transactions: {df_new_tx['award_id'].nunique():,}")
print(f"Unique award_ids in awards dataset: {df_aw['award_id'].nunique():,}")

# Check for overlaps
transaction_award_ids = set(df_new_tx['award_id'])
awards_award_ids = set(df_aw['award_id'])

overlap = transaction_award_ids.intersection(awards_award_ids)
only_in_transactions = transaction_award_ids - awards_award_ids
only_in_awards = awards_award_ids - transaction_award_ids

print(f"\nAward IDs in both datasets: {len(overlap):,}")
print(f"Award IDs only in transactions: {len(only_in_transactions):,}")
print(f"Award IDs only in awards: {len(only_in_awards):,}")
# Out:
# === Award ID Coverage ===
# Unique award_ids in new transactions: 1,522
# Unique award_ids in awards dataset: 9,872
#
# Award IDs in both datasets: 739
# Award IDs only in transactions: 783
# Award IDs only in awards: 9,133

# %%
print("=== Performing Left Join ===")
print("Joining new_transactions to awards on award_id...")

joined_df = df_new_tx.merge(
    df_aw,
    on='award_id',
    how='left',
    suffixes=('_transaction', '_award'),
    indicator=True
)

print(f"\nJoined dataframe shape: {joined_df.shape}")
print(f"Columns: {joined_df.shape[1]}")
# Out:
# === Performing Left Join ===
# Joining new_transactions to awards on award_id...
#
# Joined dataframe shape: (1550, 42)
# Columns: 42

# %%
sum(joined_df._merge == 'both'), sum(joined_df._merge == 'left_only')
# Out:
# (755, 795)

# %%
joined_df
# Out:
#       transaction_id           award_id action_date action_type  \
# 0          354207030      140L0626C0003  2026-01-07
# 1          354207621      36C10G26K0214  2026-01-07
# 2          354207876      36C77626K0030  2026-01-07
# 3          354212325  70Z08526F37008B00  2026-01-07
# 4          354212144     693KA826F00060  2026-01-07
# ...              ...                ...         ...         ...
# 1545       280243879      36C25226N0090  2025-10-10
# 1546       291044254    693C7326F00001N  2025-10-10
# 1547       280159963      36C24826N0088  2025-10-10
# 1548       280309099      36C25726N0072  2025-10-10
# 1549       279977798      36C10G26K0063  2025-10-10
#
#      action_type_description modification_number  federal_action_obligation  \
# 0                    Unknown                   0                 4182501.33
# 1                    Unknown                   0                31668429.52
# 2                    Unknown                   0                  914136.52
# 3                    Unknown                   0                 1970353.72
# 4                    Unknown                   0                 1197780.00
# ...                      ...                 ...                        ...
# 1545                 Unknown                   0                 1387158.87
# 1546                 Unknown                   0                 5734999.50
# 1547                 Unknown                   0                 3796534.85
# 1548                 Unknown                   0                 2787350.00
# 1549                 Unknown                   0                 1086991.96
#
#       total_dollars_obligated award_type_transaction  \
# 0                  4182501.33    DEFINITIVE CONTRACT
# 1                 31668429.52         DELIVERY ORDER
# 2                   914136.52         DELIVERY ORDER
# 3                  1970353.72         DELIVERY ORDER
# 4                  1197780.00         DELIVERY ORDER
# ...                       ...                    ...
# 1545               1387158.87         DELIVERY ORDER
# 1546               5734999.50         DELIVERY ORDER
# 1547               3796534.85         DELIVERY ORDER
# 1548               2787350.00         DELIVERY ORDER
# 1549               1086991.96         DELIVERY ORDER
#
#                           award_description_transaction  \
# 0                GAOA HOT WELL DUNES CAMPGRND IMPRVMNTS
# 1                      EXPRESS REPORT: DECEMBER FY26 Q1
# 2     EXPRESS REPORT: DECEMBER 2025 ORDERING OFFICER...
# 3     VARIOUS PARTS TO BE USED FOR MAINTENANCE OF RO...
# 4     TASK ORDER 1 83" X 25 DEEP, WITH SPECIAL DESIG...
# ...                                                 ...
# 1545  ORDERING PERIOD 3 PATHOLOGY, TRANSPLANT, AND E...
# 1546  AR ERFO FS OZSTF810 2022-1(1): THE PROJECT CON...
# 1547                                       LENALIDOMIDE
# 1548       STX SPECIALIZED REFERENCE LABORATORY TESTING
# 1549                     EXPRESS REPORT: SEPTEMBER 2025
#
#      period_of_performance_start_date period_of_performance_current_end_date  \
# 0                          2026-01-07                                   None
# 1                          2025-12-01                                   None
# 2                          2025-12-01                                   None
# 3                          2026-01-07                                   None
# 4                          2026-01-07                                   None
# ...                               ...                                    ...
# 1545                       2025-11-01                                   None
# 1546                       2025-10-10                                   None
# 1547                       2025-10-10                                   None
# 1548                       2026-01-01                                   None
# 1549                       2025-09-01                                   None
#
#                  awarding_agency_name         awarding_sub_agency_name  \
# 0          Department of the Interior        Bureau of Land Management
# 1      Department of Veterans Affairs   Department of Veterans Affairs
# 2      Department of Veterans Affairs   Department of Veterans Affairs
# 3     Department of Homeland Security                 U.S. Coast Guard
# 4        Department of Transportation  Federal Aviation Administration
# ...                               ...                              ...
# 1545   Department of Veterans Affairs   Department of Veterans Affairs
# 1546     Department of Transportation   Federal Highway Administration
# 1547   Department of Veterans Affairs   Department of Veterans Affairs
# 1548   Department of Veterans Affairs   Department of Veterans Affairs
# 1549   Department of Veterans Affairs   Department of Veterans Affairs
#
#                   funding_agency_name  \
# 0          Department of the Interior
# 1      Department of Veterans Affairs
# 2      Department of Veterans Affairs
# 3     Department of Homeland Security
# 4        Department of Transportation
# ...                               ...
# 1545   Department of Veterans Affairs
# 1546     Department of Transportation
# 1547   Department of Veterans Affairs
# 1548   Department of Veterans Affairs
# 1549   Department of Veterans Affairs
#
#                              recipient_name_transaction  \
# 0                                CAPEX CONSTRUCTION LLC
# 1                      TRIWEST HEALTHCARE ALLIANCE CORP
# 2                                    MANUS MEDICAL, LLC
# 3                     ROLLS-ROYCE SOLUTIONS AMERICA INC
# 4                                    GAW ASSOCIATES INC
# ...                                                 ...
# 1545  UNIVERSITY OF WISCONSIN HOSPITALS AND CLINICS ...
# 1546                             ECLIPSE COMPANIES, LLC
# 1547                         EXELAN PHARMACEUTICALS INC
# 1548                     NEOGENOMICS LABORATORIES, INC.
# 1549          VETERANS HEALTHCARE SUPPLY SOLUTIONS, INC
#
#      recipient_uei_transaction naics_code_transaction product_or_service_code  \
# 0                 VJWLNDEBBDM5                 237990                    Y1PA
# 1                 J7M9HPTGJ1S9                 524292                    Q999
# 2                 M4UBTVGBJMT7                 339113                    6515
# 3                 HYGLK2BNFKB3                 333618                    2815
# 4                 HJLHM7VX3WM3                 332322                    7H20
# ...                        ...                    ...                     ...
# 1545              UEYKTPWSV9Q9                 621511                    Q515
# 1546              RMCMTCKHMFH9                 237310                    Y1LB
# 1547              FYZXNHSQTMG8                 325412                    6505
# 1548              ML9LFC5CK7K9                 621511                    Q301
# 1549              TLTXKMLQEYU9                 334510                    6515
#
#      place_of_performance_state_transaction   ingested_at_transaction  \
# 0                                        AZ  2026-01-09T18:04:38.179Z
# 1                                        AK  2026-01-09T18:04:38.180Z
# 2                                        VA  2026-01-09T18:04:38.180Z
# 3                                        MI  2026-01-09T18:04:38.180Z
# 4                                        NJ  2026-01-09T18:04:38.180Z
# ...                                     ...                       ...
# 1545                                     WI  2026-01-09T18:04:38.263Z
# 1546                                     AR  2026-01-09T18:04:38.263Z
# 1547                                     FL  2026-01-09T18:04:38.263Z
# 1548                                     FL  2026-01-09T18:04:38.263Z
# 1549                                     FL  2026-01-09T18:04:38.263Z
#
#                                  source_url_transaction award_type_award  \
# 0       https://www.usaspending.gov/award/140L0626C0003          Unknown
# 1       https://www.usaspending.gov/award/36C10G26K0214          Unknown
# 2       https://www.usaspending.gov/award/36C77626K0030              NaN
# 3     https://www.usaspending.gov/award/70Z08526F370...              NaN
# 4      https://www.usaspending.gov/award/693KA826F00060              NaN
# ...                                                 ...              ...
# 1545    https://www.usaspending.gov/award/36C25226N0090              NaN
# 1546  https://www.usaspending.gov/award/693C7326F00001N          Unknown
# 1547    https://www.usaspending.gov/award/36C24826N0088          Unknown
# 1548    https://www.usaspending.gov/award/36C25726N0072          Unknown
# 1549    https://www.usaspending.gov/award/36C10G26K0063              NaN
#
#       award_amount award_date  start_date    end_date last_modified_date  \
# 0       4182501.33             2026-01-07  2026-09-16         2026-01-07
# 1      31668429.52             2025-12-01  2025-12-31         2026-01-07
# 2              NaN        NaN         NaN         NaN                NaN
# 3              NaN        NaN         NaN         NaN                NaN
# 4              NaN        NaN         NaN         NaN                NaN
# ...            ...        ...         ...         ...                ...
# 1545           NaN        NaN         NaN         NaN                NaN
# 1546    5734999.50             2025-10-10  2027-05-10         2025-10-10
# 1547    3796534.85             2025-10-10  2026-09-30         2025-10-10
# 1548    2787350.00             2026-01-01  2026-12-31         2025-10-10
# 1549           NaN        NaN         NaN         NaN                NaN
#
#      base_obligation_date                 awarding_agency  \
# 0              2026-01-07      Department of the Interior
# 1              2026-01-07  Department of Veterans Affairs
# 2                     NaN                             NaN
# 3                     NaN                             NaN
# 4                     NaN                             NaN
# ...                   ...                             ...
# 1545                  NaN                             NaN
# 1546           2025-10-10    Department of Transportation
# 1547           2025-10-10  Department of Veterans Affairs
# 1548           2025-10-10  Department of Veterans Affairs
# 1549                  NaN                             NaN
#
#                  awarding_sub_agency                  funding_agency  \
# 0          Bureau of Land Management      Department of the Interior
# 1     Department of Veterans Affairs  Department of Veterans Affairs
# 2                                NaN                             NaN
# 3                                NaN                             NaN
# 4                                NaN                             NaN
# ...                              ...                             ...
# 1545                             NaN                             NaN
# 1546  Federal Highway Administration    Department of Transportation
# 1547  Department of Veterans Affairs  Department of Veterans Affairs
# 1548  Department of Veterans Affairs  Department of Veterans Affairs
# 1549                             NaN                             NaN
#
#                   recipient_name_award recipient_uei_award  \
# 0               CAPEX CONSTRUCTION LLC        VJWLNDEBBDM5
# 1     TRIWEST HEALTHCARE ALLIANCE CORP        J7M9HPTGJ1S9
# 2                                  NaN                 NaN
# 3                                  NaN                 NaN
# 4                                  NaN                 NaN
# ...                                ...                 ...
# 1545                               NaN                 NaN
# 1546            ECLIPSE COMPANIES, LLC        RMCMTCKHMFH9
# 1547        EXELAN PHARMACEUTICALS INC        FYZXNHSQTMG8
# 1548    NEOGENOMICS LABORATORIES, INC.        ML9LFC5CK7K9
# 1549                               NaN                 NaN
#
#      recipient_business_categories  \
# 0                               []
# 1                               []
# 2                              NaN
# 3                              NaN
# 4                              NaN
# ...                            ...
# 1545                           NaN
# 1546                            []
# 1547                            []
# 1548                            []
# 1549                           NaN
#
#                                 award_description_award naics_code_award  \
# 0                GAOA HOT WELL DUNES CAMPGRND IMPRVMNTS           237990
# 1                      EXPRESS REPORT: DECEMBER FY26 Q1           524292
# 2                                                   NaN              NaN
# 3                                                   NaN              NaN
# 4                                                   NaN              NaN
# ...                                                 ...              ...
# 1545                                                NaN              NaN
# 1546  AR ERFO FS OZSTF810 2022-1(1): THE PROJECT CON...           237310
# 1547                                       LENALIDOMIDE           325412
# 1548       STX SPECIALIZED REFERENCE LABORATORY TESTING           621511
# 1549                                                NaN              NaN
#
#      psc_code place_of_performance_state_award         ingested_at_award  \
# 0        None                               AZ  2026-01-10T14:30:16.569Z
# 1        None                               AK  2026-01-10T14:30:16.553Z
# 2         NaN                              NaN                       NaN
# 3         NaN                              NaN                       NaN
# 4         NaN                              NaN                       NaN
# ...       ...                              ...                       ...
# 1545      NaN                              NaN                       NaN
# 1546     None                               AR  2026-01-10T14:30:16.567Z
# 1547     None                               FL  2026-01-10T14:30:16.569Z
# 1548     None                               FL  2026-01-10T14:30:16.573Z
# 1549      NaN                              NaN                       NaN
#
#                                  source_url_award     _merge
# 0     https://www.usaspending.gov/award/354207030       both
# 1     https://www.usaspending.gov/award/354207621       both
# 2                                             NaN  left_only
# 3                                             NaN  left_only
# 4                                             NaN  left_only
# ...                                           ...        ...
# 1545                                          NaN  left_only
# 1546  https://www.usaspending.gov/award/291044254       both
# 1547  https://www.usaspending.gov/award/280159963       both
# 1548  https://www.usaspending.gov/award/280309099       both
# 1549                                          NaN  left_only
#
# [1550 rows x 42 columns]

# %%
sum(df_aw.base_obligation_date == df_aw.last_modified_date), len(df_aw)
# Out:
# (471, 10000)

# %%
sum(joined_df.base_obligation_date == joined_df.last_modified_date)
# Out:
# 472

# %%
df_aw.last_modified_date.nunique(), df_aw.last_modified_date.min(), df_aw.last_modified_date.max()
# Out:
# (80, '2025-10-09', '2026-01-08')

# %%
df_aw.head(2)
# Out:
#           award_id award_type   award_amount award_date  start_date  \
# 0  DEAC0500OR22725    Unknown 40399143444.29             1999-10-15
# 1      DENA0003525    Unknown 39308850163.32             2017-01-18
#
#      end_date last_modified_date base_obligation_date       awarding_agency  \
# 0  2030-03-31         2025-12-23           1999-10-15  Department of Energy
# 1  2027-04-30         2025-12-30           2016-12-16  Department of Energy
#
#     awarding_sub_agency         funding_agency  \
# 0  Department of Energy   Department of Energy
# 1  Department of Energy  Department of Defense
#
#                                       recipient_name recipient_uei  \
# 0                                    UT-BATTELLE LLC  ZLHJJ57QA2H8
# 1  NATIONAL TECHNOLOGY & ENGINEERING SOLUTIONS OF...  LUJEPCRRT377
#
#   recipient_business_categories  \
# 0                            []
# 1                            []
#
#                                    award_description naics_code psc_code  \
# 0  MANAGEMENT AND OPERATION OF THE OAK RIDGE NATI...     561210     None
# 1  IGF::CL,CT::IGF CONTRACT AWARD DE-NA0003525 TO...     561210     None
#
#   place_of_performance_state               ingested_at  \
# 0                         TN  2026-01-10T14:30:16.542Z
# 1                         NM  2026-01-10T14:30:16.543Z
#
#                                     source_url
# 0  https://www.usaspending.gov/award/295476106
# 1  https://www.usaspending.gov/award/295527116

# %%
df_tx.head(2)
# Out:
#    transaction_id         award_id action_date action_type  \
# 0       277837703    140P2025C0024  2026-01-07           L
# 1       291029792  6913G625C100006  2026-01-07           M
#
#   action_type_description modification_number  federal_action_obligation  \
# 0                       L              P00006                   18758.44
# 1                       M              P00001                       0.00
#
#    total_dollars_obligated           award_type  \
# 0                 18758.44  DEFINITIVE CONTRACT
# 1                     0.00  DEFINITIVE CONTRACT
#
#                                    award_description  \
# 0  GOGA 253655 REHABILITATE DETERIORATED CHINA BE...
# 1  FMCSA PHASE IIB AWARD WITH PULSAR INFORMATICS,...
#
#   period_of_performance_start_date period_of_performance_current_end_date  \
# 0                       2025-02-07                                   None
# 1                       2025-04-21                                   None
#
#            awarding_agency_name  \
# 0    Department of the Interior
# 1  Department of Transportation
#
#                             awarding_sub_agency_name  \
# 0                              National Park Service
# 1  Immediate Office of the Secretary of Transport...
#
#             funding_agency_name            recipient_name recipient_uei  \
# 0    Department of the Interior           ARANA GROUP INC  VUGLHDG2RCH9
# 1  Department of Transportation  PULSAR INFORMATICS, INC.  G6MEDJJBE8F7
#
#   naics_code product_or_service_code place_of_performance_state  \
# 0     236220                    Z2JZ                         CA
# 1     541715                    AS12                         WA
#
#                 ingested_at                                         source_url
# 0  2026-01-09T18:04:38.178Z    https://www.usaspending.gov/award/140P2025C0024
# 1  2026-01-09T18:04:38.179Z  https://www.usaspending.gov/award/6913G625C100006
